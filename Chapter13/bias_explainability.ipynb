# %%
from sagemaker import Session  

session = Session() 

bucket = session.default_bucket() 

prefix = "sagemaker/bias_explain" 

region = session.boto_region_name 

# Define IAM role 

from sagemaker import get_execution_role 

import pandas as pd 

import numpy as np 

import os 

import boto3  

role = get_execution_role() 

s3_client = boto3.client("s3")
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
training_data = pd.read_csv("data/churn.csv").dropna() 

training_data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
from sklearn.model_selection import train_test_split 

churn_train, churn_test = train_test_split (training_data, test_size=0.2)

# %%
from sklearn import preprocessing
def number_encode_features(df): 

    result = df.copy() 

    encoders = {} 

    for column in result.columns: 

        if result.dtypes[column] == object: 

            encoders[column] = preprocessing.LabelEncoder() 

            result[column] = encoders[column].fit_transform(result[column].fillna("None")) 
    return result, encoders

# %%
churn_train = pd.concat([churn_train["Exited"], churn_train.drop(["Exited"], axis=1)], axis=1)
churn_train, _ = number_encode_features(churn_train)
churn_train.to_csv("data/train_churn.csv", index=False, header=False)

churn_test, _ = number_encode_features(churn_test)
churn_features = churn_test.drop(["Exited"], axis=1)
churn_target = churn_test["Exited"]
churn_features.to_csv("data/test_churn.csv", index=False, header=False)

# %%
from sagemaker.s3 import S3Uploader 

from sagemaker.inputs import TrainingInput 

train_uri = S3Uploader.upload("data/train_churn.csv", "s3://{}/{}".format(bucket, prefix)) 

train_input = TrainingInput(train_uri, content_type="csv") 

test_uri = S3Uploader.upload("data/test_churn.csv", "s3://{}/{}".format(bucket, prefix))
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
from sagemaker.image_uris import retrieve 

from sagemaker.estimator import Estimator 

container = retrieve("xgboost", region, version="1.2-1") 

xgb = Estimator(container,role, instance_count=1,instance_type="ml.m5.xlarge", disable_profiler=True,sagemaker_session=session,) 

xgb.set_hyperparameters(max_depth=5, eta=0.2,gamma=4,min_child_weight=6,subsample=0.8,objective="binary:logistic",num_round=800,) 

xgb.fit({"train": train_input}, logs=False)
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2024-03-12-01-51-01-628
# 2024-03-12 01:51:02 Starting - Starting the training job.
# 2024-03-12 01:51:16 Starting - Preparing the instances for training......
# 2024-03-12 01:51:51 Downloading - Downloading input data...
# 2024-03-12 01:52:09 Downloading - Downloading the training image.......
# 2024-03-12 01:52:50 Training - Training image download completed. Training in progress...
# 2024-03-12 01:53:05 Uploading - Uploading generated training model.
# 2024-03-12 01:53:16 Completed - Training job completed

# %%
model_name = "churn-clarify-model" 

model = xgb.create_model(name=model_name) 

container_def = model.prepare_container_def() 

session.create_model(model_name, role, container_def)
# Out:
# INFO:sagemaker:Creating model with name: churn-clarify-model
# WARNING:sagemaker:Using already existing model: churn-clarify-model
# 'churn-clarify-model'

# %%
from sagemaker import clarify 

clarify_processor = clarify.SageMakerClarifyProcessor( 

    role=role, instance_count=1, instance_type="ml.m5.xlarge", sagemaker_session=session)
# Out:
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: 1.0.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.

# %%
bias_report_output_path = "s3://{}/{}/clarify-bias".format(bucket, prefix) 

bias_data_config = clarify.DataConfig( 

    s3_data_input_path=train_uri, 

    s3_output_path=bias_report_output_path, 

    label="Exited", 

    headers=churn_train.columns.to_list(), 

    dataset_type="text/csv")

# %%
model_config = clarify.ModelConfig( 

    model_name=model_name, instance_type="ml.m5.xlarge", 

    instance_count=1,accept_type="text/csv", 

content_type="text/csv",)

# %%
predictions_config = clarify.ModelPredictedLabelConfig(probability_threshold=0.8)

# %%
bias_config = clarify.BiasConfig( 

    label_values_or_threshold=[1], facet_name="Gender", facet_values_or_threshold=[0])

# %%
clarify_processor.run_bias( 

    data_config=bias_data_config, 

    bias_config=bias_config, 

    model_config=model_config, 

    model_predicted_label_config=predictions_config, 

    pre_training_methods="all", 

    post_training_methods="all")
# Out:
# INFO:sagemaker.clarify:Analysis Config: {'dataset_type': 'text/csv', 'headers': ['Exited', 'RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary'], 'label': 'Exited', 'label_values_or_threshold': [1], 'facet': [{'name_or_index': 'Gender', 'value_or_threshold': [0]}], 'methods': {'report': {'name': 'report', 'title': 'Analysis Report'}, 'pre_training_bias': {'methods': 'all'}, 'post_training_bias': {'methods': 'all'}}, 'predictor': {'model_name': 'churn-clarify-model', 'instance_type': 'ml.m5.xlarge', 'initial_instance_count': 1, 'accept_type': 'text/csv', 'content_type': 'text/csv'}, 'probability_threshold': 0.8}
# INFO:sagemaker:Creating processing-job with name Clarify-Bias-2024-03-12-02-00-00-572
# .............................2024-03-12 02:04:43,265 logging.conf not found when configuring logging, using default logging configuration.
# 2024-03-12 02:04:43,266 Starting SageMaker Clarify Processing job
# 2024-03-12 02:04:43,267 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2024-03-12 02:04:43,267 Analysis result path: /opt/ml/processing/output
# 2024-03-12 02:04:43,268 This host is algo-1.
# 2024-03-12 02:04:43,268 This host is the leader.
# 2024-03-12 02:04:43,268 Number of hosts in the cluster is 1.
# 2024-03-12 02:04:43,546 Running Python / Pandas based analyzer.
# 2024-03-12 02:04:43,546 Dataset type: text/csv uri: /opt/ml/processing/input/data
# 2024-03-12 02:04:43,556 Loading dataset...
# /usr/local/lib/python3.9/site-packages/analyzer/data_loading/csv_data_loader.py:336: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_tmp, ignore_index=True)
# 2024-03-12 02:04:43,575 Loaded dataset. Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        8000 non-null   int64
#  1   CustomerId       8000 non-null   int64
#  2   Surname          8000 non-null   int64
#  3   CreditScore      8000 non-null   int64
#  4   Geography        8000 non-null   int64
#  5   Gender           8000 non-null   int64
#  6   Age              8000 non-null   int64
#  7   Tenure           8000 non-null   int64
#  8   Balance          8000 non-null   float64
#  9   NumOfProducts    8000 non-null   int64
#  10  HasCrCard        8000 non-null   int64
#  11  IsActiveMember   8000 non-null   int64
#  12  EstimatedSalary  8000 non-null   float64
# dtypes: float64(2), int64(11)
# memory usage: 812.6 KB
# 2024-03-12 02:04:43,661 Spinning up shadow endpoint
# 2024-03-12 02:04:43,662 Creating endpoint-config with name sm-clarify-config-1710209083-7dee
# 2024-03-12 02:04:44,113 Creating endpoint: 'sm-clarify-churn-clarify-model-1710209084-68a6'
# 2024-03-12 02:04:44,171 No endpoints ruleset found for service sagemaker-internal, falling back to legacy endpoint routing.
# 2024-03-12 02:04:44,715 Using endpoint name: sm-clarify-churn-clarify-model-1710209084-68a6
# 2024-03-12 02:04:44,715 Waiting for endpoint ...
# 2024-03-12 02:04:44,715 Checking endpoint status:
# Legend:
# (OutOfService: x, Creating: -, Updating: -, InService: !, RollingBack: <, Deleting: o, Failed: *)
# 2024-03-12 02:08:45,434 Endpoint is in service after 241 seconds
# 2024-03-12 02:08:45,435 Endpoint ready.
# 2024-03-12 02:08:45,435 ======================================
# 2024-03-12 02:08:45,435 Calculating post-training bias metrics
# 2024-03-12 02:08:45,435 ======================================
# 2024-03-12 02:08:45,435 Getting predictions from the endpoint
# 2024-03-12 02:08:46,386 We assume a prediction above 0.800 indicates 1 and below or equal indicates 0.
# 2024-03-12 02:08:46,386 Column Exited with data uniqueness fraction 0.00025 is classifed as a CATEGORICAL column
# 2024-03-12 02:08:46,389 Column Gender with data uniqueness fraction 0.00025 is classifed as a CATEGORICAL column
# /usr/local/lib/python3.9/site-packages/smclarify/bias/report.py:591: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(facet_column.name, 1)
# 2024-03-12 02:08:46,390 Column Exited with data uniqueness fraction 0.00025 is classifed as a CATEGORICAL column
# 2024-03-12 02:08:46,392 Column None with data uniqueness fraction 0.00025 is classifed as a CATEGORICAL column
# 2024-03-12 02:08:46,396 CDDPL metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/report.py", line 323, in _categorical_metric_call_wrapper
#     metric_value = smclarify.bias.metrics.call_metric(
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/metrics/posttraining.py", line 277, in CDDPL
#     return common.CDD(feature, sensitive_facet_index, positive_predicted_label_index, group_variable)
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/metrics/common.py", line 100, in CDD
#     raise ValueError("Group variable is empty or not provided")
# ValueError: Group variable is empty or not provided
# 2024-03-12 02:08:46,729 Calculated global analysis with predictor
# 2024-03-12 02:08:46,729 Stop using endpoint: sm-clarify-churn-clarify-model-1710209084-68a6
# 2024-03-12 02:08:46,729 Deleting endpoint configuration with name: sm-clarify-config-1710209083-7dee
# 2024-03-12 02:08:46,875 Deleting endpoint with name: sm-clarify-churn-clarify-model-1710209084-68a6
# 2024-03-12 02:08:46,965 Model endpoint delivered 1.54522 requests per second and a total of 2 requests over 1 seconds
# 2024-03-12 02:08:46,965 =====================================
# 2024-03-12 02:08:46,965 Calculating pre-training bias metrics
# 2024-03-12 02:08:46,965 =====================================
# 2024-03-12 02:08:46,966 Column Exited with data uniqueness fraction 0.00025 is classifed as a CATEGORICAL column
# 2024-03-12 02:08:46,968 Column Gender with data uniqueness fraction 0.00025 is classifed as a CATEGORICAL column
# /usr/local/lib/python3.9/site-packages/smclarify/bias/report.py:591: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(facet_column.name, 1)
# 2024-03-12 02:08:46,970 Column Exited with data uniqueness fraction 0.00025 is classifed as a CATEGORICAL column
# 2024-03-12 02:08:46,971 CDDL metrics failed
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/report.py", line 323, in _categorical_metric_call_wrapper
#     metric_value = smclarify.bias.metrics.call_metric(
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/metrics/__init__.py", line 27, in call_metric
#     return metric(**{key: kwargs[key] for key in inspect.signature(metric).parameters.keys()})
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/metrics/pretraining.py", line 195, in CDDL
#     return common.CDD(feature, sensitive_facet_index, positive_label_index, group_variable)
#   File "/usr/local/lib/python3.9/site-packages/smclarify/bias/metrics/common.py", line 100, in CDD
#     raise ValueError("Group variable is empty or not provided")
# ValueError: Group variable is empty or not provided
# 2024-03-12 02:08:47,011 ======================================
# 2024-03-12 02:08:47,011 Calculating bias statistics for report
# 2024-03-12 02:08:47,011 ======================================
# 2024-03-12 02:08:47,011 Column Exited with data uniqueness fraction 0.00025 is classifed as a CATEGORICAL column
# 2024-03-12 02:08:47,013 Column Gender with data uniqueness fraction 0.00025 is classifed as a CATEGORICAL column
# /usr/local/lib/python3.9/site-packages/smclarify/bias/report.py:591: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop(facet_column.name, 1)
# 2024-03-12 02:08:47,015 Column Exited with data uniqueness fraction 0.00025 is classifed as a CATEGORICAL column
# 2024-03-12 02:08:47,016 Column None with data uniqueness fraction 0.00025 is classifed as a CATEGORICAL column
# 2024-03-12 02:08:47,021 Column Exited with data uniqueness fraction 0.00025 is classifed as a CATEGORICAL column
# 2024-03-12 02:08:47,022 Column None with data uniqueness fraction 0.00025 is classifed as a CATEGORICAL column
# 2024-03-12 02:08:47,030 Converting Pandas DataFrame to SparkDataFrame for computing report metadata
# ---!02:08:48.754 [main] WARN  o.a.hadoop.util.NativeCodeLoader - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# #015[Stage 0:>                                                          (0 + 4) / 4]#015#015                                                                                #015#015[Stage 3:>                                                          (0 + 4) / 4]#015#015                                                                                #0152024-03-12 02:08:59,339 Calculated global analysis without predictor
# 2024-03-12 02:08:59,339 Stop using endpoint: None
# 2024-03-12 02:09:00,468 ['jupyter', 'nbconvert', '--to', 'html', '--output', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.ipynb', '--template', 'sagemaker-xai']
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 743469 bytes to /opt/ml/processing/output/report.html
# 2024-03-12 02:09:01,757 ['wkhtmltopdf', '-q', '--enable-local-file-access', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.pdf']
# 2024-03-12 02:09:02,834 Collected analyses:
# {
#     "version": "1.0",
#     "post_training_bias_metrics": {
#         "label": "Exited",
#         "facets": {
#             "Gender": [
#                 {
#                     "value_or_threshold": "0",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": 0.034045427661758665
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": null,
#                             "error": "Group variable is empty or not provided"
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": 0.0024038461538461453
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": 0.6109038461538461
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": -0.04493048848423331
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 2.0103030637593156
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": -0.057705224112366664
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": -0.045242306382580644
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": 0.11316588462600055
#                         },
#                         {
#                             "name": "GE",
#                             "description": "Generalized Entropy (GE)",
#                             "value": 0.06689337851671635
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": -0.09889186343527057
#                         },
#                         {
#                             "name": "SD",
#                             "description": "Specificity Difference (SD)",
#                             "value": -0.0003684598378776993
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": "-Infinity"
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     },
#     "pre_training_bias_metrics": {
#         "label": "Exited",
#         "facets": {
#             "Gender": [
#                 {
#                     "value_or_threshold": "0",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": null,
#                             "error": "Group variable is empty or not provided"
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": 0.09425
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": -0.09119862306863258
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.006415527540228706
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": 0.02439291703829674
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.09119862306863269
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.1289743296134121
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.09119862306863263
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     }
# }
# 2024-03-12 02:09:02,835 exit_message: Completed: SageMaker XAI Analyzer ran successfully

# %%
shap_config = clarify.SHAPConfig( 

    baseline=[churn_features.iloc[0].values.tolist()], 

    num_samples=15, 

    agg_method="mean_abs", 

    save_local_shap_values=True,)

# %%
explainability_output_path = "s3://{}/{}/clarify-explainability".format(bucket, prefix) 

explainability_data_config = clarify.DataConfig( 

    s3_data_input_path=train_uri, 

    s3_output_path=explainability_output_path, 

    label="Exited", 

    headers=churn_train.columns.to_list(), 

    dataset_type="text/csv")

# %%
clarify_processor.run_explainability( 

    data_config=explainability_data_config, 

    model_config=model_config, 

    explainability_config=shap_config,)
# Out:
# INFO:sagemaker.clarify:Analysis Config: {'dataset_type': 'text/csv', 'headers': ['Exited', 'RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary'], 'label': 'Exited', 'predictor': {'model_name': 'churn-clarify-model', 'instance_type': 'ml.m5.xlarge', 'initial_instance_count': 1, 'accept_type': 'text/csv', 'content_type': 'text/csv'}, 'methods': {'report': {'name': 'report', 'title': 'Analysis Report'}, 'shap': {'use_logit': False, 'save_local_shap_values': True, 'baseline': [[8741.0, 15570908.0, 447.0, 687.0, 2.0, 0.0, 29.0, 7.0, 93617.07, 1.0, 0.0, 1.0, 113050.92]], 'num_samples': 15, 'agg_method': 'mean_abs'}}}
# INFO:sagemaker:Creating processing-job with name Clarify-Explainability-2024-03-12-02-12-04-862
# .............................2024-03-12 02:16:53,488 logging.conf not found when configuring logging, using default logging configuration.
# 2024-03-12 02:16:53,489 Starting SageMaker Clarify Processing job
# 2024-03-12 02:16:53,491 Analysis config path: /opt/ml/processing/input/config/analysis_config.json
# 2024-03-12 02:16:53,491 Analysis result path: /opt/ml/processing/output
# 2024-03-12 02:16:53,492 This host is algo-1.
# 2024-03-12 02:16:53,492 This host is the leader.
# 2024-03-12 02:16:53,492 Number of hosts in the cluster is 1.
# 2024-03-12 02:16:53,776 Running Python / Pandas based analyzer.
# 2024-03-12 02:16:53,776 Dataset type: text/csv uri: /opt/ml/processing/input/data
# 2024-03-12 02:16:53,786 Loading dataset...
# /usr/local/lib/python3.9/site-packages/analyzer/data_loading/csv_data_loader.py:336: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_tmp, ignore_index=True)
# 2024-03-12 02:16:53,805 Loaded dataset. Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        8000 non-null   int64
#  1   CustomerId       8000 non-null   int64
#  2   Surname          8000 non-null   int64
#  3   CreditScore      8000 non-null   int64
#  4   Geography        8000 non-null   int64
#  5   Gender           8000 non-null   int64
#  6   Age              8000 non-null   int64
#  7   Tenure           8000 non-null   int64
#  8   Balance          8000 non-null   float64
#  9   NumOfProducts    8000 non-null   int64
#  10  HasCrCard        8000 non-null   int64
#  11  IsActiveMember   8000 non-null   int64
#  12  EstimatedSalary  8000 non-null   float64
# dtypes: float64(2), int64(11)
# memory usage: 812.6 KB
# 2024-03-12 02:16:53,901 Spinning up shadow endpoint
# 2024-03-12 02:16:53,902 Creating endpoint-config with name sm-clarify-config-1710209813-4498
# 2024-03-12 02:16:54,332 Creating endpoint: 'sm-clarify-churn-clarify-model-1710209814-ca97'
# 2024-03-12 02:16:54,390 No endpoints ruleset found for service sagemaker-internal, falling back to legacy endpoint routing.
# 2024-03-12 02:16:55,004 Using endpoint name: sm-clarify-churn-clarify-model-1710209814-ca97
# 2024-03-12 02:16:55,004 Waiting for endpoint ...
# 2024-03-12 02:16:55,004 Checking endpoint status:
# Legend:
# (OutOfService: x, Creating: -, Updating: -, InService: !, RollingBack: <, Deleting: o, Failed: *)
# 2024-03-12 02:19:55,583 Endpoint is in service after 181 seconds
# 2024-03-12 02:19:55,583 Endpoint ready.
# 2024-03-12 02:19:55,696 Clarify Kernel SHAP n_coalitions: 15, n_instances: 1, n_features_to_explain: 13, model_output_size: 1
# 2024-03-12 02:19:55,696 =====================================================
# 2024-03-12 02:19:55,696 Shap analyzer: explaining 8000 rows, 13 columns...
# 2024-03-12 02:19:55,696 =====================================================
#   0% (0 of 8000) |                       | Elapsed Time: 0:00:00 ETA:  --:--:--
#  35% (2875 of 8000) |#######             | Elapsed Time: 0:00:30 ETA:   0:00:53
#  75% (6012 of 8000) |###############     | Elapsed Time: 0:01:00 ETA:   0:00:19
# 100% (8000 of 8000) |####################| Elapsed Time: 0:01:18 Time:  0:01:18
# 2024-03-12 02:21:14,516 getting explanations took 78.82 seconds.
# 2024-03-12 02:21:14,516 ===================================================
# 2024-03-12 02:21:14,517 Falling back to generic labels: label0, label1, ...
# 2024-03-12 02:21:15,069 converting explanations to tabular took 0.55 seconds.
# 2024-03-12 02:21:15,069 ===================================================
# 2024-03-12 02:21:15,072 Wrote baseline used to compute explanations to: /opt/ml/processing/output/explanations_shap/baseline.csv
# 2024-03-12 02:21:15,253 Wrote 8000 local explanations to: /opt/ml/processing/output/explanations_shap/out.csv
# 2024-03-12 02:21:15,253 writing local explanations took 0.18 seconds.
# 2024-03-12 02:21:15,253 ===================================================
# /usr/local/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# 2024-03-12 02:21:15,256 aggregating local explanations took 0.00 seconds.
# 2024-03-12 02:21:15,256 ===================================================
# 2024-03-12 02:21:15,256 Shap analysis finished.
# 2024-03-12 02:21:15,256 Calculated global analysis with predictor
# 2024-03-12 02:21:15,256 Stop using endpoint: sm-clarify-churn-clarify-model-1710209814-ca97
# 2024-03-12 02:21:15,257 Deleting endpoint configuration with name: sm-clarify-config-1710209813-4498
# 2024-03-12 02:21:15,487 Deleting endpoint with name: sm-clarify-churn-clarify-model-1710209814-ca97
# 2024-03-12 02:21:15,591 Model endpoint delivered 100.43513 requests per second and a total of 8002 requests over 80 seconds
# 2024-03-12 02:21:15,591 Calculated global analysis without predictor
# 2024-03-12 02:21:18,071 Stop using endpoint: None
# 2024-03-12 02:21:47,669 ['jupyter', 'nbconvert', '--to', 'html', '--output', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.ipynb', '--template', 'sagemaker-xai']
# [NbConvertApp] Converting notebook /opt/ml/processing/output/report.ipynb to html
# [NbConvertApp] Writing 590290 bytes to /opt/ml/processing/output/report.html
# 2024-03-12 02:21:48,734 ['wkhtmltopdf', '-q', '--enable-local-file-access', '/opt/ml/processing/output/report.html', '/opt/ml/processing/output/report.pdf']
# 2024-03-12 02:21:49,427 Collected analyses:
# {
#     "version": "1.0",
#     "explanations": {
#         "kernel_shap": {
#             "label0": {
#                 "global_shap_values": {
#                     "RowNumber": 0.03720768026916862,
#                     "CustomerId": 0.03393801553239052,
#                     "Surname": 0.03486376368781445,
#                     "CreditScore": 0.034075126178341866,
#                     "Geography": 0.038676049585996616,
#                     "Gender": 0.03220378266077229,
#                     "Age": 0.09730495583526075,
#                     "Tenure": 0.029621360873647834,
#                     "Balance": 0.042662388375263774,
#                     "NumOfProducts": 0.05575042173153205,
#                     "HasCrCard": 0.02491129157589829,
#                     "IsActiveMember": 0.03727773509084648,
#                     "EstimatedSalary": 0.05888622379844757
#                 },
#                 "expected_value": 0.08384295552968979
#             }
#         }
#     }
# }
# 2024-03-12 02:21:49,428 exit_message: Completed: SageMaker XAI Analyzer ran successfully
# --!
